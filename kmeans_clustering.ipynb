# %%
# ! pip install scikit-learn matplotlib numpy

import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Define dataset from the image
points = np.array([
    [1, 1], [2, 1], [4, 3], [5, 6], [7, 6], [8, 8]
])

# %%
# Plot the clustered points
plt.figure(figsize=(10, 6))
plt.scatter(points[:, 0], points[:, 1], color='blue', s=100)

# Formatting the plot
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.xticks(range(0, 11))
plt.yticks(range(0, 11))
plt.grid(True, linestyle="--", alpha=0.5)
plt.title("Given Data Points")
plt.show()

# %%
# Choose number of clusters (K)
k = 2 
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
kmeans.fit(points)
# Out:
# KMeans(n_clusters=2, n_init=10, random_state=42)

# %%
# Get cluster labels and centroids
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
# Plot the clustered points
plt.figure(figsize=(10, 6))
plt.scatter(points[:, 0], points[:, 1], c=labels, cmap='winter', s=100, alpha=0.6, label="Data Points")
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='*', s=100, label="Centroids")

# Formatting the plot
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.xticks(range(0, 11))
plt.yticks(range(0, 11))
plt.grid(True, linestyle="--", alpha=0.5)
plt.title("K-Means Clustering Example")
plt.legend()
plt.show()

# %%
# Print cluster centers
print("Cluster Centroids:")
print(centroids)
# Out:
# Cluster Centroids:
# [[2.33333333 1.66666667]
#  [6.66666667 6.66666667]]
